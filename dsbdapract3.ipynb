# %%
import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("bank_data_set - bank_data_set.csv")

# %%
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit      object
# dtype: object

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
df["education"].unique()
# Out:
# array(['secondary', 'tertiary', 'primary', 'unknown'], dtype=object)

# %%
#plt.pie(df["education"].value_counts(),labels=df["education"].value_counts().index, autopct= "%1.1f%%")
plt.pie(df["education"].value_counts(),autopct="%1.1f%%")
label=['secondary', 'tertiary', 'primary', 'unknown']
plt.legend(label)
print("Inference : pie chart shows percentage of distinct education holders")
# Out:
# Inference : pie chart shows percentage of distinct education holders

# %%
plt.figure(figsize=(15,9))
plt.barh(df["age"],df["job"])
plt.xlabel("jobs")
plt.ylabel("age")
print("Inference: graph shows horizontal bar graph where x value takes verically and y value take horizonnatlly and bar's are plotted horizontally")
# Out:
# Inference: graph shows horizontal bar graph where x value takes verically and y value take horizonnatlly and bar's are plotted horizontally

# %%
sns.pairplot(df)
print("Inference : this graph shows relationship between each pair of numerical value ,it is for diffrent variables")
# Out:
# Inference : this graph shows relationship between each pair of numerical value ,it is for diffrent variables

# %%
sns.scatterplot(x="age",y="balance",data=df)
plt.xlabel("Age")
plt.ylabel("balance")
print("scatterplot is used to relationship between two numerical values here we showing reklationship between age and balance.on x axis there is a age and on y axis there is balanace")
# Out:
# scatterplot is used to relationship between two numerical values here we showing reklationship between age and balance.on x axis there is a age and on y axis there is balanace

# %%
sns.barplot(x="month",y="duration",data=df)
#df["campaign"].unique()
plt.title ("barplot between month and duration")
print("Inference : barplot shows mean of numerical variable(duration) grouped by categorical variable (month).here on x axis it gives categorical value i.e month and on y axis it gives mean of numeric variable duration")
# Out:
# Inference : barplot shows mean of numerical variable(duration) grouped by categorical variable (month).here on x axis it gives categorical value i.e month and on y axis it gives mean of numeric variable duration

# %%
plt.plot(df['balance'][:100], marker = 'o', color = 'blue', label = 'age')
plt.xlabel("Age")
plt.ylabel("Balance")
print("Inference : lineplot shows a balance acc0rding to age groups. on x axis it take values of ages and on y axis it takes values of balance corresponding to them")
# Out:
# Inference : lineplot shows a balance acc0rding to age groups. on x axis it take values of ages and on y axis it takes values of balance corresponding to them

# %%
plt.bar(df["job"][:20],df["marital"][:20])
#plt.subtitle("job vs marital status")
plt.xlabel("jobs")
plt.ylabel("marital status")

print("Inference : bar graph gives values of first 20 job holders and their marital status. On X axis it gives value of diffrent jobs and on Y axis it give marital status of that job holders")
# Out:
# Inference : bar graph gives values of first 20 job holders and their marital status. On X axis it gives value of diffrent jobs and on Y axis it give marital status of that job holders

# %%
df["job"].unique()
# Out:
# array(['admin.', 'technician', 'services', 'management', 'retired',
#        'blue-collar', 'unemployed', 'entrepreneur', 'housemaid',
#        'unknown', 'self-employed', 'student'], dtype=object)

# %%
plt.figure(figsize=(8,8))
plt.pie(df["job"].value_counts(),labels=df["job"].value_counts().index,autopct= "1.1f%%")
#plt.labels=(['admin.', 'technician', 'services', 'management', 'retired',
       #'blue-collar', 'unemployed', 'entrepreneur', 'housemaid',
       #'unknown', 'self-employed', 'student'])
#plt.legend(labels)
plt.title=("Distinct jobs percentage")
print("Inference : Pie chart gives percentage of distinct job" )
# Out:
# Inference : Pie chart gives percentage of distinct job

# %%
 df.hist(column='job', by='deposit', bins=25 ,figsize=(8,5),layout=(2,2))
print("Inference: Graph shows histogram for job column by is their deposite value is yes or no i.e distribution of job holders between they deposite or not ")
# Out:
# Inference: Graph shows histogram for job column by is their deposite value is yes or no i.e distribution of job holders between they deposite or not

# %%
print(" Age Distribution: Shows the distribution of customers' ages.")
print("   Inference: Most customers are aged between 25-50.")
sns.histplot(df['age'], bins=30, kde=True,  color='skyblue')
# Out:
#  Age Distribution: Shows the distribution of customers' ages.
#    Inference: Most customers are aged between 25-50.
# <Axes: xlabel='age', ylabel='Count'>

# %%
print(" Balance Distribution: Displays the distribution of account balances.")
print("   Inference: A few customers have extremely high balances, suggesting income disparity.")
sns.histplot(df['balance'], bins=30, kde=True,color='orange')
#plt.title("Balance Distribution")
plt.show()
# Out:
#  Balance Distribution: Displays the distribution of account balances.
#    Inference: A few customers have extremely high balances, suggesting income disparity.

# %%
print("Duration Distribution: Shows call duration distribution.")
print("   Inference: Longer call durations may indicate better engagement.")
sns.histplot(df['duration'], bins=30, kde=True, color='purple')
#axes[0, 2].set_title("Duration Distribution")
# Out:
# Duration Distribution: Shows call duration distribution.
#    Inference: Longer call durations may indicate better engagement.
# <Axes: xlabel='duration', ylabel='Count'>

# %%
print(" Job Distribution: Displays the count of different job categories.")
print("   Inference: Admin and blue-collar jobs are most common.")
sns.countplot(y=df['job'], order=df['job'].value_counts().index)
#axes[1, 0].set_title("Job Distribution")
# Out:
#  Job Distribution: Displays the count of different job categories.
#    Inference: Admin and blue-collar jobs are most common.
# <Axes: xlabel='count', ylabel='job'>

# %%
print(" Marital Status Distribution: Shows the marital status distribution.")
print("   Inference: Majority of customers are married.")
sns.countplot(x=df['marital'])
#axes[1, 1].set_title("Marital Status Distribution")
# Out:
#  Marital Status Distribution: Shows the marital status distribution.
#    Inference: Majority of customers are married.
# <Axes: xlabel='marital', ylabel='count'>

# %%
print(" Education Distribution: Shows different education levels.")
print("   Inference: Secondary education is the most common.")
sns.countplot(x=df['education'])
#axes[1, 2].set_title("Education Distribution")
# Out:
#  Education Distribution: Shows different education levels.
#    Inference: Secondary education is the most common.
# <Axes: xlabel='education', ylabel='count'>

# %%
print(" Age vs Balance Scatter Plot: Analyzes relationship between age and balance.")
print("   Inference: No strong correlation between age and balance.")
sns.scatterplot(x=df['age'], y=df['balance'], alpha=0.5, color='green')
#axes[3, 0].set_title("Age vs. Balance")
# Out:
#  Age vs Balance Scatter Plot: Analyzes relationship between age and balance.
#    Inference: No strong correlation between age and balance.
# <Axes: xlabel='age', ylabel='balance'>

# %%
print(" Balance vs Deposit Box Plot: Compares balance with deposit status.")
print("   Inference: Higher balances may lead to higher deposits.")
sns.boxplot(x='deposit', y='balance', data=df)
#axes[3, 1].set_title("Balance vs. Deposit")
# Out:
#  Balance vs Deposit Box Plot: Compares balance with deposit status.
#    Inference: Higher balances may lead to higher deposits.
# <Axes: xlabel='deposit', ylabel='balance'>

# %%
print(" Campaign vs Deposit Box Plot: Analyzes impact of campaigns on deposits.")
print("   Inference: Fewer calls often result in successful deposits.")
plt.figure(figsize=(5, 2))
sns.boxplot(x='deposit', y='campaign', data=df)
#plt.title("Campaign vs. Deposit")
plt.show()
# Out:
#  Campaign vs Deposit Box Plot: Analyzes impact of campaigns on deposits.
#    Inference: Fewer calls often result in successful deposits.

# %%
print("Correlation Heatmap: Shows correlations between numerical variables.")
print("    Inference: Duration has the highest correlation with deposits.")
plt.figure(figsize=(6, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
#plt.title("Correlation Heatmap")
plt.show()
# Out:
# Correlation Heatmap: Shows correlations between numerical variables.
#     Inference: Duration has the highest correlation with deposits.

# %%
print(" Pairplot: Displays pairwise relationships in the dataset.")
sns.pairplot(df, hue='deposit', diag_kind='kde')
plt.show()
# Out:
#  Pairplot: Displays pairwise relationships in the dataset.
