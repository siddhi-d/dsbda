# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("dataset_Facebook - dataset_Facebook.csv" , sep=",")

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df["Paid"].median()
# Out:
# np.float64(0.0)

# %%
df["Paid"]=df["Paid"].fillna(df["Paid"].median())

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df["like"].median()
# Out:
# np.float64(101.0)

# %%
df["like"]=df["like"].fillna(df["like"].median())

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df["share"].median()
# Out:
# np.float64(19.0)

# %%
df["share"]=df["share"].fillna(df["share"].median())

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df1=df[df["Page total likes"]>=100000].loc[0:15]

# %%
df1
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 6             139441   Photo         3          12             1          3
# 7             139441   Photo         3          12             7          9
# 8             139441  Status         2          12             7          3
# 9             139441   Photo         3          12             6         10
# 10            139441  Status         2          12             5         10
# ...

# %%
df2=df[(df["Paid"]==0)&(df["like"]>=50)].loc[0:15]

# %%
df2
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 8             139441  Status         2          12             7          3
# 9             139441   Photo         3          12             6         10
# 10            139441  Status         2          12             5         10
# 11            139441   Photo         2          12             5         10
# 12            139441   Photo         2          12             5         10
# 13            139441   Photo         2          12             5          3
# ...

# %%
df3=df[(df["comment"]>0)].loc[0:15]

# %%
df3
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 6             139441   Photo         3          12             1          3
# 9             139441   Photo         3          12             6         10
# 13            139441   Photo         2          12             5          3
# 14            138414   Photo         2          12             4          5
# 15            138414  Status         2          12             3         10
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
df4=df[(df["Post Hour"]>=2)&(df["share"]>10)].loc[0:15]

# %%
df4
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 6             139441   Photo         3          12             1          3
# 7             139441   Photo         3          12             7          9
# 8             139441  Status         2          12             7          3
# 9             139441   Photo         3          12             6         10
# 10            139441  Status         2          12             5         10
# ...

# %%
merging=pd.concat([df1,df2,df4],axis=0)

# %%
merging
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 6             139441   Photo         3          12             1          3
# 7             139441   Photo         3          12             7          9
# 8             139441  Status         2          12             7          3
# 9             139441   Photo         3          12             6         10
# 10            139441  Status         2          12             5         10
# ...

# %%
merging.shape
# Out:
# (43, 19)

# %%
sub1=df[["Page total likes","Type","Lifetime Post Consumers"]].loc[0:15]

# %%
sub1
# Out:
#     Page total likes    Type  Lifetime Post Consumers
# 0             139441   Photo                      109
# 1             139441  Status                     1361
# 2             139441   Photo                      113
# 3             139441   Photo                      790
# 4             139441   Photo                      410
# 5             139441  Status                     1073
# 6             139441   Photo                      265
# 7             139441   Photo                      232
# 8             139441  Status                     1407
# 9             139441   Photo                      183
# 10            139441  Status                     4100
# 11            139441   Photo                      127
# 12            139441   Photo                      115
# 13            139441   Photo                      134
# 14            138414   Photo                      337
# 15            138414  Status                     1209

# %%
sub2=df[["Total Interactions","Lifetime Post Consumers"]].loc[0:15]

# %%
sub2
# Out:
#     Total Interactions  Lifetime Post Consumers
# 0                  100                      109
# 1                  164                     1361
# 2                   80                      113
# 3                 1777                      790
# 4                  393                      410
# 5                  186                     1073
# 6                  279                      265
# 7                  339                      232
# 8                  192                     1407
# 9                  142                      183
# 10                 252                     4100
# 11                 106                      127
# 12                 104                      115
# 13                 152                      134
# 14                 599                      337
# 15                 108                     1209

# %%
sub3=df[["share","Lifetime Post Consumers"]].loc[0:15]

# %%
sub3
# Out:
#     share  Lifetime Post Consumers
# 0    17.0                      109
# 1    29.0                     1361
# 2    14.0                      113
# 3   147.0                      790
# 4    49.0                      410
# 5    33.0                     1073
# 6    27.0                      265
# 7    14.0                      232
# 8    31.0                     1407
# 9    26.0                      183
# 10   19.0                     4100
# 11   18.0                      127
# 12   14.0                      115
# 13   10.0                      134
# 14   20.0                      337
# 15   18.0                     1209

# %%
m=pd.merge(sub1,sub2,on="Lifetime Post Consumers")

# %%
m
# Out:
#     Page total likes    Type  Lifetime Post Consumers  Total Interactions
# 0             139441   Photo                      109                 100
# 1             139441  Status                     1361                 164
# 2             139441   Photo                      113                  80
# 3             139441   Photo                      790                1777
# 4             139441   Photo                      410                 393
# 5             139441  Status                     1073                 186
# 6             139441   Photo                      265                 279
# 7             139441   Photo                      232                 339
# 8             139441  Status                     1407                 192
# 9             139441   Photo                      183                 142
# 10            139441  Status                     4100                 252
# 11            139441   Photo                      127                 106
# ...

# %%
m.shape
# Out:
# (16, 4)

# %%
mer=pd.merge(sub1,sub2,on="Lifetime Post Consumers")
mer
# Out:
#     Page total likes    Type  Lifetime Post Consumers  Total Interactions
# 0             139441   Photo                      109                 100
# 1             139441  Status                     1361                 164
# 2             139441   Photo                      113                  80
# 3             139441   Photo                      790                1777
# 4             139441   Photo                      410                 393
# 5             139441  Status                     1073                 186
# 6             139441   Photo                      265                 279
# 7             139441   Photo                      232                 339
# 8             139441  Status                     1407                 192
# 9             139441   Photo                      183                 142
# 10            139441  Status                     4100                 252
# 11            139441   Photo                      127                 106
# ...

# %%
sort=df.sort_values(by="Page total likes",ascending=True)

# %%
sort
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 498             81370   Photo         3           1             4         11
# 497             81370   Photo         1           1             5          2
# 496             81370   Photo         2           1             5          8
# 495             85093   Photo         3           1             7          2
# ..                ...     ...       ...         ...           ...        ...
# 3              139441   Photo         2          12             2         10
# 2              139441   Photo         3          12             3          3
# 1              139441  Status         2          12             3         10
# 4              139441   Photo         2          12             2          3
# 0              139441   Photo         2          12             4          3
#
# ...

# %%
sort.transpose()
# Out:
#                                                       499    498    497  \
# Page total likes                                    81370  81370  81370
# Type                                                Photo  Photo  Photo
# Category                                                2      3      1
# Post Month                                              1      1      1
# Post Weekday                                            4      4      5
# Post Hour                                               4     11      2
# Paid                                                  0.0    0.0    0.0
# Lifetime Post Total Reach                            4188   4156   3778
# Lifetime Post Total Impressions                      7292   7564   7216
# Lifetime Engaged Users                                564    626    625
# Lifetime Post Consumers                               524    574    572
# Lifetime Post Consumptions                            743    832    795
# ...

# %%
pivotetable=pd.pivot_table(df,index=["Type","Category"],values="comment")

# %%
pivotetable.T
# Out:
# Type     Link               Photo                         Status            \
# Category    1    2    3         1          2         3         1         2
# comment   2.9  2.0  2.0  5.897297  11.692308  6.913333  4.333333  9.921053
#
# Type                Video
# Category     3          1
# comment   2.75  12.285714

# %%
plt.bar(df["Post Month"],df["Type"])
plt.xlabel("Post Month")
plt.ylabel("Type")
# Out:
# Text(0, 0.5, 'Type')

# %%
plt.pie(df["Type"].value_counts(),autopct="%1.1f%%")
label=["PHOTO","STATUS","LINK","VIDEO"]
plt.legend(label)

# %%
plt.barh(df["Type"],df["Lifetime Engaged Users"])
# Out:
# <BarContainer object of 500 artists>

# %%
sns.barplot(x="Post Month",y="Category",data=df)
# Out:
# <Axes: xlabel='Post Month', ylabel='Category'>

# %%
sns.scatterplot(y="Total Interactions",x="Page total likes",data=df)
# Out:
# <Axes: xlabel='Page total likes', ylabel='Total Interactions'>

# %%
pd.melt(df, id_vars=['Category'], value_vars=['Total Interactions'])
# Out:
#      Category            variable  value
# 0           2  Total Interactions    100
# 1           2  Total Interactions    164
# 2           3  Total Interactions     80
# 3           2  Total Interactions   1777
# 4           2  Total Interactions    393
# ..        ...                 ...    ...
# 495         3  Total Interactions     84
# 496         2  Total Interactions     75
# 497         1  Total Interactions    115
# 498         3  Total Interactions    136
# 499         2  Total Interactions    119
#
# [500 rows x 3 columns]

# %%
melted=pd.melt(df, id_vars=['Post Month'], value_vars=['Type'])

# %%
melted.head(3)
# Out:
#    Post Month variable   value
# 0          12     Type   Photo
# 1          12     Type  Status
# 2          12     Type   Photo
